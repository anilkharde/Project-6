# %%
import pandas as pd
import numpy as np

# %%
file1=r"I:\data scientist using python\project3\counterfeit_train.csv"
file2=r"I:\data scientist using python\project3\counterfeit_test.csv"
counterfeit_train=pd.read_csv(file1)
counterfeit_test=pd.read_csv(file2)

# %%
counterfeit_train.head()
# Out:
#   Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0       RRA15              13.100     Area046          1995      160.2366
# 1       YVV26                 NaN     Area027          1983      110.4384
# 2       LJC15               9.025     Area046          1995      259.4092
# 3       GWC40              11.800     Area046          1995       99.9830
# 4       QMN13                 NaN     Area019          1983       56.4402
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0        Antimalarial        critical             0.070422
# 1         Mstablizers            mild             0.013000
# 2             Cardiac            mild             0.060783
# 3  OralContraceptives            mild             0.065555
# 4       Hreplacements        critical             0.248859
#
#             Area_Type Area_City_Type Area_dist_level  Counterfeit_Sales
# 0            DownTown         Tier 1           Small          1775.5026
# ...

# %%
train=counterfeit_train.copy()
test=counterfeit_test.copy()

# %%
counterfeit_train['Medicine_ID'].value_counts()
# Out:
# SCK30    9
# RQS74    9
# QLK14    9
# HQH91    9
# KIS14    9
# OQH15    9
# HHZ13    8
# RRH53    8
# USQ94    8
# PPX12    8
# CTJ12    8
# YEN19    8
# KJA29    8
# OXK54    8
# HQQ45    8
# NCN78    8
# SGZ11    8
# GVZ23    8
# QIN25    8
# DZM40    8
# RVF12    8
# VUG26    8
# NQY36    8
# NBV27    8
# SKK32    8
# KIC54    8
# IDG55    8
# WKS47    8
# HHY36    8
# UMX23    8
#         ..
# XSM88    1
# RLS13    1
# FVS71    1
# YYX14    1
# JPO54    1
# WGC12    1
# QGU83    1
# WTA87    1
# PIG89    1
# QMP15    1
# YDD11    1
# BKA11    1
# JPY13    1
# ZVH10    1
# WET13    1
# BIY14    1
# JTW13    1
# HBG12    1
# OPM10    1
# UTM98    1
# PPB10    1
# YLQ15    1
# UKN13    1
# ETU15    1
# SPK13    1
# QEG60    1
# KQB14    1
# ADE15    1
# FUN14    1
# HOA15    1
# Name: Medicine_ID, Length: 1557, dtype: int64

# %%
counterfeit_train=counterfeit_train.set_index('Medicine_ID')
counterfeit_test=counterfeit_test.set_index('Medicine_ID')

# %%
counterfeit_train[counterfeit_train['Counterfeit_Weight'].isnull()]
# Out:
#              Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# Medicine_ID
# YVV26                       NaN     Area027          1983      110.4384
# QMN13                       NaN     Area019          1983       56.4402
# RUT58                       NaN     Area019          1983      118.5280
# NNX49                       NaN     Area027          1983      255.7144
# LFG35                       NaN     Area019          1983       59.2034
# EBS47                       NaN     Area019          1983       69.8220
# MXD18                       NaN     Area027          1983      253.1512
# XDV33                       NaN     Area027          1983      207.0768
# NDK33                       NaN     Area019          1983      150.6180
# YDI38                       NaN     Area027          1983      110.0042
# IAR88                       NaN     Area019          1983      199.7872
# WKZ12                       NaN     Area027          1983      181.7422
# ...

# %%
freq=train['Medicine_ID'].value_counts()
for i in freq.index[freq>1]:
    df=counterfeit_train.loc[i]
    avg=df['Counterfeit_Weight'].mean()
    #if df['Counterfeit_Weight'].isnull().sum()>0:
    counterfeit_train['Counterfeit_Weight'][i]=np.where(counterfeit_train['Counterfeit_Weight'][i].isnull(),avg,counterfeit_train['Counterfeit_Weight'][i])
# Out:
# I:\anaconda new\install anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
counterfeit_train[counterfeit_train['Counterfeit_Weight'].isnull()]
# Out:
#              Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# Medicine_ID
# YYX14                       NaN     Area027          1983       99.2514
# ZEE32                       NaN     Area027          1983      264.5672
# WEX14                       NaN     Area019          1983       64.5298
# YDD11                       NaN     Area027          1983      130.3440
# AEF11                       NaN     Area027          1983       42.2558
# RLS13                       NaN     Area019          1983      154.1102
# LVI11                       NaN     Area019          1983       52.1454
# QMP15                       NaN     Area019          1983       92.4592
# ZEE32                       NaN     Area019          1983      266.6672
# ETU15                       NaN     Area019          1983      131.5098
# FVS71                       NaN     Area027          1983       97.2198
#
#                   Medicine_Type SidEffect_Level  Availability_rating  \
# Medicine_ID
# ...

# %%
# drop the rows whose any one column has null values 
counterfeit_train.dropna(axis=0,subset=['Counterfeit_Weight'],inplace=True)

# %%
counterfeit_train[counterfeit_train['Counterfeit_Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Counterfeit_Weight, DistArea_ID, Active_Since, Medicine_MRP, Medicine_Type, SidEffect_Level, Availability_rating, Area_Type, Area_City_Type, Area_dist_level, Counterfeit_Sales]
# Index: []

# %%
# Check correlation between variables so as to update the null values of counterfiet_Weight
# %matplotlib inline
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7*2,8.27*2)})
corr = counterfeit_train.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
corr.style.background_gradient().set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row0_col0 {
#             background-color:  #023858;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row0_col1 {
#             background-color:  #f7f0f7;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row0_col2 {
#             background-color:  #fbf3f9;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row0_col3 {
#             background-color:  #f0eaf4;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row0_col4 {
#             background-color:  #ede8f3;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row1_col0 {
#             background-color:  #fff7fb;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row1_col1 {
#             background-color:  #023858;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row1_col2 {
#             background-color:  #fef6fb;
#         }    #T_8a59d72e_0f7e_11e9_89ea_40167e83ddf3row1_col3 {
#             background-color:  #f8f1f8;
# ...

# %%
counterfeit_test[counterfeit_test['Counterfeit_Weight'].isnull()]
# Out:
#              Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# Medicine_ID
# HLZ81                       NaN     Area027          1983       85.5328
# AIR10                       NaN     Area019          1983      112.8016
# EXZ14                       NaN     Area027          1983      163.3656
# IDJ12                       NaN     Area027          1983      225.0534
# NZS82                       NaN     Area027          1983       97.7198
# UFQ12                       NaN     Area027          1983      241.0352
# SGZ11                       NaN     Area027          1983       87.3644
# HWM68                       NaN     Area027          1983       97.9856
# VLR10                       NaN     Area027          1983       66.0298
# CGG23                       NaN     Area027          1983       50.3454
# EVE11                       NaN     Area027          1983      149.4838
# LKG52                       NaN     Area027          1983      131.2756
# ...

# %%
freq=test['Medicine_ID'].value_counts()
for i in freq.index[freq>1]:
    df=counterfeit_test.loc[i]
    avg=df['Counterfeit_Weight'].mean()
    #if df['Counterfeit_Weight'].isnull().sum()>0:
    counterfeit_test['Counterfeit_Weight'][i]=np.where(counterfeit_test['Counterfeit_Weight'][i].isnull(),avg,counterfeit_test['Counterfeit_Weight'][i])
# Out:
# I:\anaconda new\install anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
counterfeit_test[counterfeit_test['Counterfeit_Weight'].isnull()]
# Out:
#              Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# Medicine_ID
# IDJ12                       NaN     Area027          1983      225.0534
# NZS82                       NaN     Area027          1983       97.7198
# UFQ12                       NaN     Area027          1983      241.0352
# VLR10                       NaN     Area027          1983       66.0298
# TYB54                       NaN     Area027          1983      184.7080
# JIV77                       NaN     Area019          1983      158.3760
# OMK35                       NaN     Area027          1983       95.4224
# XEX60                       NaN     Area027          1983       96.9198
# KIT10                       NaN     Area019          1983      179.1816
# MWN81                       NaN     Area027          1983      136.7046
# DST32                       NaN     Area027          1983      109.0700
# KBP10                       NaN     Area019          1983      166.1946
# ...

# %%
counterfeit_train['Counterfeit_Weight'].mean()
# Out:
# 14.13514984574721

# %%
avg=counterfeit_train['Counterfeit_Weight'].mean()
counterfeit_test['Counterfeit_Weight']=np.where(counterfeit_test['Counterfeit_Weight'].isnull(),avg,counterfeit_test['Counterfeit_Weight'])

# %%
counterfeit_test[counterfeit_test['Counterfeit_Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Counterfeit_Weight, DistArea_ID, Active_Since, Medicine_MRP, Medicine_Type, SidEffect_Level, Availability_rating, Area_Type, Area_City_Type, Area_dist_level]
# Index: []

# %%
counterfeit_train['Area_dist_level'].value_counts()
# Out:
# Medium     2203
# Unknown    1938
# Small      1928
# High        749
# Name: Area_dist_level, dtype: int64

# %%
train=counterfeit_train.copy()
test=counterfeit_test.copy()

# %%
train['DistArea_ID'].value_counts()
# Out:
# Area017    760
# Area013    749
# Area046    749
# Area035    748
# Area049    739
# Area045    736
# Area027    730
# Area018    729
# Area010    442
# Area019    425
# Name: DistArea_ID, dtype: int64

# %%
test['DistArea_ID'].value_counts()
# Out:
# Area027    200
# Area018    199
# Area045    193
# Area049    191
# Area013    183
# Area035    182
# Area046    181
# Area017    166
# Area010    113
# Area019     97
# Name: DistArea_ID, dtype: int64

# %%
k1=pd.get_dummies(train['DistArea_ID'],drop_first=True,prefix='DistArea_ID')
train=pd.concat([train,k1],axis=1)
del train['DistArea_ID']

# %%
k2=pd.get_dummies(test['DistArea_ID'],drop_first=True,prefix='DistArea_ID')
test=pd.concat([test,k2],axis=1)
del test['DistArea_ID']

# %%
col=2018-train['Active_Since']
k3=pd.DataFrame({'Active_Year':col})
train=pd.concat([train,k3],axis=1)
del train['Active_Since']

# %%
active_year_test=2018-test['Active_Since']
k4=pd.DataFrame({'Active_Year':active_year_test})
test=pd.concat([test,k4],axis=1)
del test['Active_Since']

# %%
train.columns
# Out:
# Index(['Counterfeit_Weight', 'Medicine_MRP', 'Medicine_Type',
#        'SidEffect_Level', 'Availability_rating', 'Area_Type', 'Area_City_Type',
#        'Area_dist_level', 'Counterfeit_Sales', 'DistArea_ID_Area013',
#        'DistArea_ID_Area017', 'DistArea_ID_Area018', 'DistArea_ID_Area019',
#        'DistArea_ID_Area027', 'DistArea_ID_Area035', 'DistArea_ID_Area045',
#        'DistArea_ID_Area046', 'DistArea_ID_Area049', 'Active_Year'],
#       dtype='object')

# %%
train.head()
# Out:
#              Counterfeit_Weight  Medicine_MRP       Medicine_Type  \
# Medicine_ID
# RRA15                    13.100      160.2366        Antimalarial
# YVV26                     7.450      110.4384         Mstablizers
# LJC15                     9.025      259.4092             Cardiac
# GWC40                    11.800       99.9830  OralContraceptives
# QMN13                     8.930       56.4402       Hreplacements
#
#             SidEffect_Level  Availability_rating           Area_Type  \
# Medicine_ID
# RRA15              critical             0.070422            DownTown
# YVV26                  mild             0.013000          CityLimits
# LJC15                  mild             0.060783            DownTown
# GWC40                  mild             0.065555            DownTown
# QMN13              critical             0.248859  MidTownResidential
#
#             Area_City_Type Area_dist_level  Counterfeit_Sales  \
# Medicine_ID
# ...

# %%
train['Medicine_Type'].value_counts()
# Out:
# Hreplacements         973
# Antibiotics           969
# Antiseptics           724
# OralContraceptives    691
# Antipyretics          535
# Cardiac               522
# Mstablizers           512
# Tranquilizers         420
# Analgesics            356
# Antimalarial          339
# Antacids              206
# Statins               166
# MuscleRelaxants       139
# Antifungal            111
# Stimulants             95
# Antiviral              49
# Name: Medicine_Type, dtype: int64

# %%
test['Medicine_Type'].value_counts()
# Out:
# Antibiotics           262
# Hreplacements         224
# Antiseptics           186
# OralContraceptives    162
# Antipyretics          146
# Mstablizers           134
# Cardiac               127
# Tranquilizers         100
# Analgesics             89
# Antimalarial           86
# Statins                47
# Antacids               45
# Antifungal             37
# MuscleRelaxants        30
# Antiviral              15
# Stimulants             15
# Name: Medicine_Type, dtype: int64

# %%
k5=pd.get_dummies(train['Medicine_Type'],drop_first=True,prefix='Medicine_Type')
train=pd.concat([train,k5],axis=1)
del train['Medicine_Type']

k6=pd.get_dummies(test['Medicine_Type'],drop_first=True,prefix='Medicine_Type')
test=pd.concat([test,k6],axis=1)
del test['Medicine_Type']

# %%
train['SidEffect_Level'].value_counts()
# Out:
# mild        4427
# critical    2380
# Name: SidEffect_Level, dtype: int64

# %%
test['SidEffect_Level'].value_counts()
# Out:
# mild        1083
# critical     622
# Name: SidEffect_Level, dtype: int64

# %%
train['SidEffect_Level_isCritical']=np.where(train['SidEffect_Level']=='critical',1,0)
del train['SidEffect_Level']

# %%
test['SidEffect_Level_isCritical']=np.where(test['SidEffect_Level']=='critical',1,0)
del test['SidEffect_Level']

# %%
test['Availability_rating'].value_counts()
# Out:
# 0.013000    107
# 0.072847      2
# 0.172721      2
# 0.173624      2
# 0.059825      2
# 0.072940      2
# 0.175462      2
# 0.110457      2
# 0.089792      2
# 0.054178      2
# 0.094097      2
# 0.093640      2
# 0.063280      1
# 0.085593      1
# 0.039980      1
# 0.058337      1
# 0.052653      1
# 0.174505      1
# 0.151680      1
# 0.030242      1
# 0.135565      1
# 0.110259      1
# 0.035639      1
# 0.099327      1
# 0.186574      1
# 0.045028      1
# 0.052356      1
# 0.116935      1
# 0.049672      1
# 0.076355      1
#            ...
# 0.150787      1
# 0.099307      1
# 0.038968      1
# 0.064909      1
# 0.125554      1
# 0.127022      1
# 0.122266      1
# 0.033953      1
# 0.058362      1
# 0.039904      1
# 0.091909      1
# 0.058166      1
# 0.019012      1
# 0.027087      1
# 0.032464      1
# 0.068840      1
# 0.031920      1
# 0.061004      1
# 0.099282      1
# 0.083288      1
# 0.033716      1
# 0.086251      1
# 0.101909      1
# 0.095602      1
# ...

# %%
train['Area_Type'].isnull().sum()
# Out:
# 0

# %%
test['Area_Type'].value_counts()
# Out:
# DownTown              1096
# MidTownResidential     210
# CityLimits             200
# Industrial             199
# Name: Area_Type, dtype: int64

# %%
k7=pd.get_dummies(train['Area_Type'],drop_first=True,prefix='Area_Type')
train=pd.concat([train,k7],axis=1)
del train['Area_Type']

k8=pd.get_dummies(test['Area_Type'],drop_first=True,prefix='Area_Type')
test=pd.concat([test,k8],axis=1)
del test['Area_Type']

# %%
train['Area_City_Type'].isnull().sum()
# Out:
# 0

# %%
train['Area_City_Type'].value_counts()
# Out:
# Tier 3    2650
# Tier 2    2244
# Tier 1    1913
# Name: Area_City_Type, dtype: int64

# %%
k9=pd.get_dummies(train['Area_City_Type'],drop_first=True,prefix='Area_City_Type')
train=pd.concat([train,k9],axis=1)
del train['Area_City_Type']

k10=pd.get_dummies(test['Area_City_Type'],drop_first=True,prefix='Area_City_Type')
test=pd.concat([test,k10],axis=1)
del test['Area_City_Type']

# %%
train.head()
# Out:
#              Counterfeit_Weight  Medicine_MRP  Availability_rating  \
# Medicine_ID
# RRA15                    13.100      160.2366             0.070422
# YVV26                     7.450      110.4384             0.013000
# LJC15                     9.025      259.4092             0.060783
# GWC40                    11.800       99.9830             0.065555
# QMN13                     8.930       56.4402             0.248859
#
#             Area_dist_level  Counterfeit_Sales  DistArea_ID_Area013  \
# Medicine_ID
# RRA15                 Small          1775.5026                    0
# YVV26                Medium          3069.1520                    0
# LJC15                 Small          2603.0920                    0
# GWC40                 Small          1101.7130                    0
# QMN13                 Small           158.9402                    0
#
#              DistArea_ID_Area017  DistArea_ID_Area018  DistArea_ID_Area019  \
# Medicine_ID
# ...

# %%
train['Area_dist_level'].isnull().sum()
# Out:
# 0

# %%
train['Area_dist_level'].value_counts()
# Out:
# Medium     2198
# Unknown    1938
# Small      1922
# High        749
# Name: Area_dist_level, dtype: int64

# %%
k11=pd.get_dummies(train['Area_dist_level'],drop_first=True,prefix='Area_dist_level')
train=pd.concat([train,k11],axis=1)
del train['Area_dist_level']

k12=pd.get_dummies(test['Area_dist_level'],drop_first=True,prefix='Area_dist_level')
test=pd.concat([test,k12],axis=1)
del test['Area_dist_level']

# %%
train.head()
# Out:
#              Counterfeit_Weight  Medicine_MRP  Availability_rating  \
# Medicine_ID
# RRA15                    13.100      160.2366             0.070422
# YVV26                     7.450      110.4384             0.013000
# LJC15                     9.025      259.4092             0.060783
# GWC40                    11.800       99.9830             0.065555
# QMN13                     8.930       56.4402             0.248859
#
#              Counterfeit_Sales  DistArea_ID_Area013  DistArea_ID_Area017  \
# Medicine_ID
# RRA15                1775.5026                    0                    0
# YVV26                3069.1520                    0                    0
# LJC15                2603.0920                    0                    0
# GWC40                1101.7130                    0                    0
# QMN13                 158.9402                    0                    0
#
#              DistArea_ID_Area018  DistArea_ID_Area019  DistArea_ID_Area027  \
# Medicine_ID
# ...

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x=train.drop('Counterfeit_Sales',axis=1)
y=train['Counterfeit_Sales']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
xtrain.head()
# Out:
#              Counterfeit_Weight  Medicine_MRP  Availability_rating  \
# Medicine_ID
# BNA31                      19.9      105.5436             0.093957
# ZDE75                      22.0      162.6366             0.052056
# YMU12                      10.9      115.3280             0.098434
# KPX48                      18.0      156.8102             0.051606
# BOM11                      12.9      178.1474             0.287592
#
#              DistArea_ID_Area013  DistArea_ID_Area017  DistArea_ID_Area018  \
# Medicine_ID
# BNA31                          0                    1                    0
# ZDE75                          0                    0                    0
# YMU12                          0                    1                    0
# KPX48                          0                    0                    0
# BOM11                          0                    0                    0
#
#              DistArea_ID_Area019  DistArea_ID_Area027  DistArea_ID_Area035  \
# ...

# %%
ytrain.head()
# Out:
# Medicine_ID
# BNA31    1909.3284
# ZDE75    2228.9124
# YMU12    2669.6720
# KPX48    2883.3938
# BOM11     449.8948
# Name: Counterfeit_Sales, dtype: float64

# %%
lm.fit(xtrain,ytrain)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
prediction=lm.predict(xtest)

# %%
from sklearn.metrics import mean_absolute_error as mae

# %%
MAE=mae(ytest,prediction)

# %%
score=1-(MAE/1660)

# %%
score
# Out:
# 0.5059199856363241

# %%
test.index
# Out:
# Index(['HLZ81', 'ECE94', 'SAD14', 'EQV63', 'AIR10', 'LIC37', 'EXZ14', 'UCB79',
#        'IDJ12', 'KLQ71',
#        ...
#        'TTJ13', 'GSV13', 'ZXN29', 'RTV34', 'VFE97', 'KXW10', 'CKE54', 'HAY13',
#        'ZEE32', 'NDL93'],
#       dtype='object', name='Medicine_ID', length=1705)

# %%
submission=pd.DataFrame({'Medicine_ID':test.index})
submission['Counterfeit_Sales']=lm.predict(test)

# %%
writer = pd.ExcelWriter('submission_project3_1.xlsx')
submission.to_excel(writer,index=False)
writer.save()
